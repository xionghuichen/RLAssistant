# %% [markdown]
# # V2

# %%
from RLA.easy_plot.plot_func_v2 import plot_func

# %%
data_root='simplest_code'
task = 'demo_task'
regs = [
    '2022/03/01/21-[12]*'
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs , split_keys=['learning_rate'], 
              metrics=['perf/mse', 'y_out'])
# Out:
# searching 2022/03/01/21-[12]*
# find log simplest_code/log/demo_task/2022/03/01/21-26-59-653703 11.0.91.89 &env_id=Test-v1&learning_rate=0.001&seed=88
# find log simplest_code/log/demo_task/2022/03/01/21-22-58-846147 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888
# find log simplest_code/log/demo_task/2022/03/01/21-13-58-909376 11.0.91.89 &env_id=Test-v1&learning_rate=0.01
# find log simplest_code/log/demo_task/2022/03/01/21-13-03-230208 11.0.91.89 &env_id=Test-v1&learning_rate=0.0001
# find log simplest_code/log/demo_task/2022/03/01/21-20-23-748368 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=8888
# skipping progress file in  simplest_code/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log simplest_code/log/demo_task/2022/03/01/21-23-31-383753 11.0.91.89 &env_id=Test-v1&learning_rate=0.001&seed=888
# find log number 6
# --- complete process ---

# %% [markdown]
# # V1 (deprecated)

# %%
from RLA.easy_plot.plot_func import plot_res_func

# %%
task='demo_task'
location = 'simplest_code/log/' + task 
regs = [
    '2022/03/01/21-[12]*'
]
_ = plot_res_func(prefix_dir=location, regs=regs , param_keys=['learning_rate'], 
                  value_keys=['perf/mse'], 
                  y_bound=0.1,
#                   replace_legend_keys=["X"],  bound_line=[[perf_map[task], 'grey', '--', 'BC']],
#                   resample=1024, smooth_step=10, legend_outside=False,  title='', use_buf=False, 
                  verbose=False,
                  xlabel='epochs', 
                  ylabel='reward ratio', 
                  shaded_range=False,
                  pretty=True, 
                  save_name='simple_res.pdf')
# Out:
# skipping progress file in  simplest_code/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# learning_rate=0.0001 eval:perf/mse (1)-err : (0.02 \pm 0.00)
# learning_rate=0.001 eval:perf/mse (2)-err : (0.00 \pm 0.00)
# learning_rate=0.01 eval:perf/mse (3)-err : (0.00 \pm 0.00)
# --- complete process ---
# saved location: simplest_code/results/easy_plot/demo_task/simple_res.pdf

# %%
task='demo_task'
location = 'sb3_ppo_example/log/' + task 
regs = [
    '2022/03/03/15-03-03-761940*'
]
_ = plot_res_func(prefix_dir=location, regs=regs , param_keys=['env'], 
                  value_keys=['rollout/ep_rew_mean'], 
#                   y_bound=0.1,
#                   replace_legend_keys=["X"],  bound_line=[[perf_map[task], 'grey', '--', 'BC']],
#                   resample=1024, smooth_step=10,  title='', use_buf=False, 
                  verbose=False,
                  xlabel='epochs', 
                  legend_outside=True, 
                  ylabel='reward ratio', 
                  shaded_range=False,
                  pretty=True, 
                  save_name='ppo_torch_res.pdf')
# Out:
# env=CartPole-v1 eval:rollout/ep_rew_mean (1)-err : (500.00 \pm 0.00)
# --- complete process ---
# saved location: sb3_ppo_example/results/easy_plot/demo_task/ppo_torch_res.pdf

# %%
task='demo_task'
location = 'sb3_ppo_example/log/' + task 
regs = [
    '2022/03/03/15-03-03-761940*'
]
_ = plot_res_func(prefix_dir=location, regs=regs , param_keys=['env'], 
                  value_keys=['train/approx_kl', 'train/value_loss'], 
                  y_bound=0.1,
#                   replace_legend_keys=["X"],  bound_line=[[perf_map[task], 'grey', '--', 'BC']],
#                   resample=1024, smooth_step=10,  title='', use_buf=False, 
                  verbose=False,
                  xlabel='epochs', 
                  legend_outside=True, 
                  ylabel='reward ratio', 
                  shaded_range=False,
                  pretty=True, 
                  save_name='ppo_torch_val.pdf')
# Out:
# env=CartPole-v1 eval:train/approx_kl (1)-err : (0.00 \pm 0.00)
# env=CartPole-v1 eval:train/value_loss (1)-err : (0.00 \pm 0.00)
# --- complete process ---
# saved location: sb3_ppo_example/results/easy_plot/demo_task/ppo_torch_val.pdf

# %%
task='demo_task'
location = 'sb_ppo_example/log/' + task 
regs = [
    '2022/03/03/15-25*'
]
_ = plot_res_func(prefix_dir=location, regs=regs , param_keys=['env'], 
                  value_keys=['perf/episode_reward'], 
#                   y_bound=0.1,
#                   replace_legend_keys=["X"],  bound_line=[[perf_map[task], 'grey', '--', 'BC']],
#                   resample=1024, smooth_step=10,  title='', use_buf=False, 
                  verbose=False,
                  xlabel='epochs', 
                  legend_outside=True, 
                  ylabel='reward ratio', 
                  shaded_range=False,
                  pretty=True, 
                  save_name='ppo_torch_val.pdf')
# Out:
# env=Reacher-v2 eval:perf/episode_reward (1)-err : (-1.71 \pm 0.00)
# --- complete process ---
# saved location: sb_ppo_example/results/easy_plot/demo_task/ppo_torch_val.pdf
